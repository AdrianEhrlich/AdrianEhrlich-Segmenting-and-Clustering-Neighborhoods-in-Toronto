# %% [markdown]
# ## Segmenting and Clustering Neighborhoods in Toronto - Part 1

# %% [markdown]
# Importing libraries

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
! conda install -c conda-forge folium
! pip install folium
import folium
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors
from geopy.geocoders import Nominatim
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: folium in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (0.12.1)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium) (0.4.2)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium) (1.19.2)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium) (2.11.3)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium) (2.22.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium) (2.8)

# %% [markdown]
# Extracting data from Wikipedia

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
html_data = requests.get(url).text
soup = BeautifulSoup(html_data, 'html5lib')

# %% [markdown]
# Scraping the datata into a dataframe

# %%
table_contents=[]
table=soup.find('table')
for row in table.findAll('td'):
    cell = {}
    if row.span.text=='Not assigned':
        pass
    else:
        cell['PostalCode'] = row.p.text[:3]
        cell['Borough'] = (row.span.text).split('(')[0]
        cell['Neighborhood'] = (((((row.span.text).split('(')[1]).strip(')')).replace(' /',',')).replace(')',' ')).strip(' ')
        table_contents.append(cell)

# print(table_contents)
df=pd.DataFrame(table_contents)
df['Borough']=df['Borough'].replace({'Downtown TorontoStn A PO Boxes25 The Esplanade':'Downtown Toronto Stn A',
                                             'East TorontoBusiness reply mail Processing Centre969 Eastern':'East Toronto Business',
                                             'EtobicokeNorthwest':'Etobicoke Northwest','East YorkEast Toronto':'East York/East Toronto',
                                             'MississaugaCanada Post Gateway Processing Centre':'Mississauga'})

# %%
df.head(10)
# Out:
#   PostalCode           Borough                      Neighborhood
# 0        M3A        North York                         Parkwoods
# 1        M4A        North York                  Victoria Village
# 2        M5A  Downtown Toronto         Regent Park, Harbourfront
# 3        M6A        North York  Lawrence Manor, Lawrence Heights
# 4        M7A      Queen's Park     Ontario Provincial Government
# 5        M9A         Etobicoke                  Islington Avenue
# 6        M1B       Scarborough                    Malvern, Rouge
# 7        M3B        North York                   Don Mills North
# 8        M4B         East York   Parkview Hill, Woodbine Gardens
# 9        M5B  Downtown Toronto          Garden District, Ryerson

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ## Part 2

# %% [markdown]
# ### Getting the geographical coordinates of the neighborhoods using the GeoSpatial Dataset

# %%
url2='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/labs_v1/Geospatial_Coordinates.csv'

coordinates = pd.read_csv(url2)
coordinates.head(10)
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476
# 5         M1J  43.744734 -79.239476
# 6         M1K  43.727929 -79.262029
# 7         M1L  43.711112 -79.284577
# 8         M1M  43.716316 -79.239476
# 9         M1N  43.692657 -79.264848

# %% [markdown]
# Merging dataframes

# %%
coordinates.rename(columns={"Postal Code": "PostalCode"}, inplace=True)
df = df.join(coordinates.set_index('PostalCode'), on='PostalCode')
df.head(10)
# Out:
#   PostalCode           Borough                      Neighborhood   Latitude  \
# 0        M3A        North York                         Parkwoods  43.753259
# 1        M4A        North York                  Victoria Village  43.725882
# 2        M5A  Downtown Toronto         Regent Park, Harbourfront  43.654260
# 3        M6A        North York  Lawrence Manor, Lawrence Heights  43.718518
# 4        M7A      Queen's Park     Ontario Provincial Government  43.662301
# 5        M9A         Etobicoke                  Islington Avenue  43.667856
# 6        M1B       Scarborough                    Malvern, Rouge  43.806686
# 7        M3B        North York                   Don Mills North  43.745906
# 8        M4B         East York   Parkview Hill, Woodbine Gardens  43.706397
# 9        M5B  Downtown Toronto          Garden District, Ryerson  43.657162
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494
# 5 -79.532242
# 6 -79.194353
# 7 -79.352188
# 8 -79.309937
# 9 -79.378937

# %% [markdown]
# ## Part 3

# %% [markdown]
# ### Explore and cluster the neighborhoods in Toronto

# %% [markdown]
# Map of the city with neighborhoods superimposed

# %%
# getting the coordinates of Toronto
address = 'Toronto'

geolocator = Nominatim(user_agent="toronto-explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# %%
# create the map of Toronto
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a84f616fb0294a0a9d001bd86ddef121%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a84f616fb0294a0a9d001bd86ddef121%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a84f616fb0294a0a9d001bd86ddef121%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_a84f616fb0294a0a9d001bd86ddef121%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# Selecting the boroughs that contain the word Toronto and creating a map to show them

# %%
df_toronto_borough = df[df['Borough'].str.contains("Toronto")].reset_index(drop=True)

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_toronto_borough['Latitude'], df_toronto_borough['Longitude'], df_toronto_borough['Borough'], df_toronto_borough['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_5ab15903f07443f691cea0544881a80b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_5ab15903f07443f691cea0544881a80b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_5ab15903f07443f691cea0544881a80b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_5ab15903f07443f691cea0544881a80b%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# Explore neighborhoods wiht Foursquare

# %%
CLIENT_ID = 'UMAHH11LV5ZCHZOSPLPTXCRMMH25ARQKISU2DGVAWRM3QWYN' 
CLIENT_SECRET = '4QLBJT0HWROGTCJUEB144WIVJJ5DY31CFVLRPKBUU0LKN4BL' 
VERSION = '20180604' 
LIMIT = 100

# %%
df_toronto_borough.head(10)
# Out:
#   PostalCode                 Borough                  Neighborhood   Latitude  \
# 0        M5A        Downtown Toronto     Regent Park, Harbourfront  43.654260
# 1        M5B        Downtown Toronto      Garden District, Ryerson  43.657162
# 2        M5C        Downtown Toronto                St. James Town  43.651494
# 3        M4E            East Toronto                   The Beaches  43.676357
# 4        M5E        Downtown Toronto                   Berczy Park  43.644771
# 5        M5G        Downtown Toronto            Central Bay Street  43.657952
# 6        M6G        Downtown Toronto                      Christie  43.669542
# 7        M5H        Downtown Toronto      Richmond, Adelaide, King  43.650571
# 8        M6H            West Toronto  Dufferin, Dovercourt Village  43.669005
# 9        M4J  East York/East Toronto            The Danforth  East  43.685347
#
#    Longitude
# 0 -79.360636
# 1 -79.378937
# 2 -79.375418
# 3 -79.293031
# 4 -79.373306
# 5 -79.387383
# 6 -79.422564
# 7 -79.384568
# 8 -79.442259
# 9 -79.338106

# %% [markdown]
# Get venues by borough and neighborhood

# %%
def getNearbyVenues(boroughs, neighborhoods, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for borough, neighborhood, lat, lng in zip(boroughs, neighborhoods, latitudes, longitudes):
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            borough,
            neighborhood, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = [
                  'Borough',
                  'Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
borough_neighborhood_venues = getNearbyVenues(boroughs=df_toronto_borough['Borough'],
                                             neighborhoods=df_toronto_borough['Neighborhood'],
                                             latitudes=df_toronto_borough['Latitude'],
                                             longitudes=df_toronto_borough['Longitude'])
borough_neighborhood_venues.head(10)
# Out:
#             Borough               Neighborhood  Neighborhood Latitude  \
# 0  Downtown Toronto  Regent Park, Harbourfront               43.65426
# 1  Downtown Toronto  Regent Park, Harbourfront               43.65426
# 2  Downtown Toronto  Regent Park, Harbourfront               43.65426
# 3  Downtown Toronto  Regent Park, Harbourfront               43.65426
# 4  Downtown Toronto  Regent Park, Harbourfront               43.65426
# 5  Downtown Toronto  Regent Park, Harbourfront               43.65426
# 6  Downtown Toronto  Regent Park, Harbourfront               43.65426
# 7  Downtown Toronto  Regent Park, Harbourfront               43.65426
# 8  Downtown Toronto  Regent Park, Harbourfront               43.65426
# 9  Downtown Toronto  Regent Park, Harbourfront               43.65426
#
#    Neighborhood Longitude                             Venue  Venue Latitude  \
# 0              -79.360636                  Roselle Desserts       43.653447
# 1              -79.360636                     Tandem Coffee       43.653559
# 2              -79.360636            Cooper Koo Family YMCA       43.653249
# 3              -79.360636                    Impact Kitchen       43.656369
# 4              -79.360636               Body Blitz Spa East       43.654735
# 5              -79.360636                   Corktown Common       43.655618
# 6              -79.360636                The Extension Room       43.653313
# 7              -79.360636          Dominion Pub and Kitchen       43.656919
# 8              -79.360636                Morning Glory Cafe       43.653947
# 9              -79.360636  The Distillery Historic District       43.650244
#
#    Venue Longitude        Venue Category
# 0       -79.362017                Bakery
# 1       -79.361809           Coffee Shop
# 2       -79.358008   Distribution Center
# 3       -79.356980            Restaurant
# 4       -79.359874                   Spa
# 5       -79.356211                  Park
# 6       -79.359725  Gym / Fitness Center
# 7       -79.358967                   Pub
# 8       -79.361149        Breakfast Spot
# 9       -79.359323         Historic Site

# %% [markdown]
# Find number of venues for each borough and neighborhood

# %%
borough_neighborhood_venues.groupby(['Borough', 'Neighborhood']).count()
# Out:
#                                                                            Neighborhood Latitude  \
# Borough                Neighborhood
# Central Toronto        Davisville                                                             34
#                        Davisville North                                                       10
#                        Forest Hill North & West                                                4
#                        Lawrence Park                                                           3
#                        Moore Park, Summerhill East                                             2
#                        North Toronto West                                                     20
#                        Roselawn                                                                3
#                        Summerhill West, Rathnelly, South Hill, Forest ...                     14
#                        The Annex, North Midtown, Yorkville                                    21
# Downtown Toronto       Berczy Park                                                            56
#                        CN Tower, King and Spadina, Railway Lands, Harb...                     15
#                        Central Bay Street                                                     70
#                        Christie                                                               16
#                        Church and Wellesley                                                   78
#                        Commerce Court, Victoria Hotel                                        100
#                        First Canadian Place, Underground city                                100
#                        Garden District, Ryerson                                              100
#                        Harbourfront East, Union Station, Toronto Islands                     100
#                        Kensington Market, Chinatown, Grange Park                              67
#                        Regent Park, Harbourfront                                              45
#                        Richmond, Adelaide, King                                              100
#                        Rosedale                                                                4
#                        St. James Town                                                         88
#                        St. James Town, Cabbagetown                                            44
#                        Toronto Dominion Centre, Design Exchange                              100
#                        University of Toronto, Harbord                                         33
# Downtown Toronto Stn A Enclave of M5E                                                         98
# East Toronto           India Bazaar, The Beaches West                                         23
#                        Studio District                                                        36
#                        The Beaches                                                             4
#                        The Danforth West, Riverdale                                           42
# East Toronto Business  Enclave of M4L                                                         16
# East York/East Toronto The Danforth  East                                                      3
# West Toronto           Brockton, Parkdale Village, Exhibition Place                           24
#                        Dufferin, Dovercourt Village                                           16
#                        High Park, The Junction South                                          24
#                        Little Portugal, Trinity                                               41
#                        Parkdale, Roncesvalles                                                 14
#                        Runnymede, Swansea                                                     35
#
#                                                                            Neighborhood Longitude  \
# Borough                Neighborhood
# Central Toronto        Davisville                                                              34
#                        Davisville North                                                        10
#                        Forest Hill North & West                                                 4
#                        Lawrence Park                                                            3
#                        Moore Park, Summerhill East                                              2
#                        North Toronto West                                                      20
#                        Roselawn                                                                 3
#                        Summerhill West, Rathnelly, South Hill, Forest ...                      14
#                        The Annex, North Midtown, Yorkville                                     21
# Downtown Toronto       Berczy Park                                                             56
#                        CN Tower, King and Spadina, Railway Lands, Harb...                      15
#                        Central Bay Street                                                      70
#                        Christie                                                                16
#                        Church and Wellesley                                                    78
#                        Commerce Court, Victoria Hotel                                         100
#                        First Canadian Place, Underground city                                 100
#                        Garden District, Ryerson                                               100
#                        Harbourfront East, Union Station, Toronto Islands                      100
#                        Kensington Market, Chinatown, Grange Park                               67
#                        Regent Park, Harbourfront                                               45
#                        Richmond, Adelaide, King                                               100
#                        Rosedale                                                                 4
#                        St. James Town                                                          88
#                        St. James Town, Cabbagetown                                             44
#                        Toronto Dominion Centre, Design Exchange                               100
#                        University of Toronto, Harbord                                          33
# Downtown Toronto Stn A Enclave of M5E                                                          98
# East Toronto           India Bazaar, The Beaches West                                          23
#                        Studio District                                                         36
#                        The Beaches                                                              4
#                        The Danforth West, Riverdale                                            42
# East Toronto Business  Enclave of M4L                                                          16
# East York/East Toronto The Danforth  East                                                       3
# West Toronto           Brockton, Parkdale Village, Exhibition Place                            24
#                        Dufferin, Dovercourt Village                                            16
#                        High Park, The Junction South                                           24
#                        Little Portugal, Trinity                                                41
#                        Parkdale, Roncesvalles                                                  14
#                        Runnymede, Swansea                                                      35
#
#                                                                            Venue  \
# Borough                Neighborhood
# Central Toronto        Davisville                                             34
#                        Davisville North                                       10
#                        Forest Hill North & West                                4
#                        Lawrence Park                                           3
#                        Moore Park, Summerhill East                             2
#                        North Toronto West                                     20
#                        Roselawn                                                3
#                        Summerhill West, Rathnelly, South Hill, Forest ...     14
#                        The Annex, North Midtown, Yorkville                    21
# Downtown Toronto       Berczy Park                                            56
#                        CN Tower, King and Spadina, Railway Lands, Harb...     15
#                        Central Bay Street                                     70
#                        Christie                                               16
#                        Church and Wellesley                                   78
#                        Commerce Court, Victoria Hotel                        100
#                        First Canadian Place, Underground city                100
#                        Garden District, Ryerson                              100
#                        Harbourfront East, Union Station, Toronto Islands     100
#                        Kensington Market, Chinatown, Grange Park              67
#                        Regent Park, Harbourfront                              45
#                        Richmond, Adelaide, King                              100
#                        Rosedale                                                4
#                        St. James Town                                         88
#                        St. James Town, Cabbagetown                            44
#                        Toronto Dominion Centre, Design Exchange              100
#                        University of Toronto, Harbord                         33
# Downtown Toronto Stn A Enclave of M5E                                         98
# East Toronto           India Bazaar, The Beaches West                         23
#                        Studio District                                        36
#                        The Beaches                                             4
#                        The Danforth West, Riverdale                           42
# East Toronto Business  Enclave of M4L                                         16
# East York/East Toronto The Danforth  East                                      3
# West Toronto           Brockton, Parkdale Village, Exhibition Place           24
#                        Dufferin, Dovercourt Village                           16
#                        High Park, The Junction South                          24
#                        Little Portugal, Trinity                               41
#                        Parkdale, Roncesvalles                                 14
#                        Runnymede, Swansea                                     35
#
#                                                                            Venue Latitude  \
# Borough                Neighborhood
# Central Toronto        Davisville                                                      34
#                        Davisville North                                                10
#                        Forest Hill North & West                                         4
#                        Lawrence Park                                                    3
#                        Moore Park, Summerhill East                                      2
#                        North Toronto West                                              20
#                        Roselawn                                                         3
#                        Summerhill West, Rathnelly, South Hill, Forest ...              14
#                        The Annex, North Midtown, Yorkville                             21
# Downtown Toronto       Berczy Park                                                     56
#                        CN Tower, King and Spadina, Railway Lands, Harb...              15
#                        Central Bay Street                                              70
#                        Christie                                                        16
#                        Church and Wellesley                                            78
#                        Commerce Court, Victoria Hotel                                 100
#                        First Canadian Place, Underground city                         100
#                        Garden District, Ryerson                                       100
#                        Harbourfront East, Union Station, Toronto Islands              100
#                        Kensington Market, Chinatown, Grange Park                       67
#                        Regent Park, Harbourfront                                       45
#                        Richmond, Adelaide, King                                       100
#                        Rosedale                                                         4
#                        St. James Town                                                  88
#                        St. James Town, Cabbagetown                                     44
#                        Toronto Dominion Centre, Design Exchange                       100
#                        University of Toronto, Harbord                                  33
# Downtown Toronto Stn A Enclave of M5E                                                  98
# East Toronto           India Bazaar, The Beaches West                                  23
#                        Studio District                                                 36
#                        The Beaches                                                      4
#                        The Danforth West, Riverdale                                    42
# East Toronto Business  Enclave of M4L                                                  16
# East York/East Toronto The Danforth  East                                               3
# West Toronto           Brockton, Parkdale Village, Exhibition Place                    24
#                        Dufferin, Dovercourt Village                                    16
#                        High Park, The Junction South                                   24
#                        Little Portugal, Trinity                                        41
#                        Parkdale, Roncesvalles                                          14
#                        Runnymede, Swansea                                              35
#
#                                                                            Venue Longitude  \
# Borough                Neighborhood
# Central Toronto        Davisville                                                       34
#                        Davisville North                                                 10
#                        Forest Hill North & West                                          4
#                        Lawrence Park                                                     3
#                        Moore Park, Summerhill East                                       2
#                        North Toronto West                                               20
#                        Roselawn                                                          3
#                        Summerhill West, Rathnelly, South Hill, Forest ...               14
#                        The Annex, North Midtown, Yorkville                              21
# Downtown Toronto       Berczy Park                                                      56
#                        CN Tower, King and Spadina, Railway Lands, Harb...               15
#                        Central Bay Street                                               70
#                        Christie                                                         16
#                        Church and Wellesley                                             78
#                        Commerce Court, Victoria Hotel                                  100
#                        First Canadian Place, Underground city                          100
#                        Garden District, Ryerson                                        100
#                        Harbourfront East, Union Station, Toronto Islands               100
#                        Kensington Market, Chinatown, Grange Park                        67
#                        Regent Park, Harbourfront                                        45
#                        Richmond, Adelaide, King                                        100
#                        Rosedale                                                          4
#                        St. James Town                                                   88
#                        St. James Town, Cabbagetown                                      44
#                        Toronto Dominion Centre, Design Exchange                        100
#                        University of Toronto, Harbord                                   33
# Downtown Toronto Stn A Enclave of M5E                                                   98
# East Toronto           India Bazaar, The Beaches West                                   23
#                        Studio District                                                  36
#                        The Beaches                                                       4
#                        The Danforth West, Riverdale                                     42
# East Toronto Business  Enclave of M4L                                                   16
# East York/East Toronto The Danforth  East                                                3
# West Toronto           Brockton, Parkdale Village, Exhibition Place                     24
#                        Dufferin, Dovercourt Village                                     16
#                        High Park, The Junction South                                    24
#                        Little Portugal, Trinity                                         41
#                        Parkdale, Roncesvalles                                           14
#                        Runnymede, Swansea                                               35
#
#                                                                            Venue Category
# Borough                Neighborhood
# Central Toronto        Davisville                                                      34
#                        Davisville North                                                10
#                        Forest Hill North & West                                         4
#                        Lawrence Park                                                    3
#                        Moore Park, Summerhill East                                      2
#                        North Toronto West                                              20
#                        Roselawn                                                         3
#                        Summerhill West, Rathnelly, South Hill, Forest ...              14
#                        The Annex, North Midtown, Yorkville                             21
# Downtown Toronto       Berczy Park                                                     56
#                        CN Tower, King and Spadina, Railway Lands, Harb...              15
#                        Central Bay Street                                              70
#                        Christie                                                        16
#                        Church and Wellesley                                            78
#                        Commerce Court, Victoria Hotel                                 100
#                        First Canadian Place, Underground city                         100
#                        Garden District, Ryerson                                       100
#                        Harbourfront East, Union Station, Toronto Islands              100
#                        Kensington Market, Chinatown, Grange Park                       67
#                        Regent Park, Harbourfront                                       45
#                        Richmond, Adelaide, King                                       100
#                        Rosedale                                                         4
#                        St. James Town                                                  88
#                        St. James Town, Cabbagetown                                     44
#                        Toronto Dominion Centre, Design Exchange                       100
#                        University of Toronto, Harbord                                  33
# Downtown Toronto Stn A Enclave of M5E                                                  98
# East Toronto           India Bazaar, The Beaches West                                  23
#                        Studio District                                                 36
#                        The Beaches                                                      4
#                        The Danforth West, Riverdale                                    42
# East Toronto Business  Enclave of M4L                                                  16
# East York/East Toronto The Danforth  East                                               3
# West Toronto           Brockton, Parkdale Village, Exhibition Place                    24
#                        Dufferin, Dovercourt Village                                    16
#                        High Park, The Junction South                                   24
#                        Little Portugal, Trinity                                        41
#                        Parkdale, Roncesvalles                                          14
#                        Runnymede, Swansea                                              35

# %% [markdown]
# Finding the top 10 venues for each neighborhood

# %%
# One hot encoding
toronto_onehot = pd.get_dummies(borough_neighborhood_venues[['Venue Category']], prefix="", prefix_sep="")

# Add neighborhood column back to dataframe
toronto_onehot['Borough'] = borough_neighborhood_venues['Borough'] 
toronto_onehot['Neighborhoods'] = borough_neighborhood_venues['Neighborhood'] 
toronto_onehot['Venue'] = borough_neighborhood_venues['Venue'] 

# Move neighborhood column to the first column
fixed_columns = list(toronto_onehot.columns[-3:]) + list(toronto_onehot.columns[:-3])
toronto_onehot = toronto_onehot[fixed_columns]

# Group rows by borough and neighborhood by the mean of the frequency of occurrence of each category
toronto_grouped = toronto_onehot.groupby(['Borough', 'Neighborhoods']).mean().reset_index()

# Print the results
num_top_venues = 10

for hood in toronto_grouped['Neighborhoods']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhoods'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[2:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Davisville----
#                 venue  freq
# 0        Dessert Shop  0.09
# 1      Sandwich Place  0.09
# 2         Pizza Place  0.06
# 3  Italian Restaurant  0.06
# 4         Coffee Shop  0.06
# 5                 Gym  0.06
# 6                Café  0.06
# 7    Sushi Restaurant  0.06
# 8            Pharmacy  0.03
# 9               Diner  0.03
#
#
# ----Davisville North----
#                   venue  freq
# 0                 Hotel   0.2
# 1                  Park   0.1
# 2           Pizza Place   0.1
# 3  Gym / Fitness Center   0.1
# 4        Breakfast Spot   0.1
# 5        Sandwich Place   0.1
# 6     Food & Drink Shop   0.1
# 7          Dance Studio   0.1
# 8      Department Store   0.1
# 9        Adult Boutique   0.0
#
#
# ----Forest Hill North & West----
#                       venue  freq
# 0                      Park  0.25
# 1                     Trail  0.25
# 2             Jewelry Store  0.25
# 3          Sushi Restaurant  0.25
# 4            Adult Boutique  0.00
# 5       Moroccan Restaurant  0.00
# 6       Martial Arts School  0.00
# 7  Mediterranean Restaurant  0.00
# 8               Men's Store  0.00
# 9             Metro Station  0.00
#
#
# ----Lawrence Park----
#                       venue  freq
# 0                      Park  0.33
# 1                  Bus Line  0.33
# 2               Swim School  0.33
# 3            Adult Boutique  0.00
# 4       Moroccan Restaurant  0.00
# 5       Martial Arts School  0.00
# 6  Mediterranean Restaurant  0.00
# 7               Men's Store  0.00
# 8             Metro Station  0.00
# 9        Mexican Restaurant  0.00
#
#
# ----Moore Park, Summerhill East----
#                       venue  freq
# 0                      Park   0.5
# 1               Summer Camp   0.5
# 2            Adult Boutique   0.0
# 3       Moroccan Restaurant   0.0
# 4                    Market   0.0
# 5       Martial Arts School   0.0
# 6  Mediterranean Restaurant   0.0
# 7               Men's Store   0.0
# 8             Metro Station   0.0
# 9        Mexican Restaurant   0.0
#
#
# ----North Toronto West----
#                  venue  freq
# 0          Coffee Shop  0.10
# 1       Clothing Store  0.10
# 2          Yoga Studio  0.05
# 3                 Café  0.05
# 4           Restaurant  0.05
# 5   Chinese Restaurant  0.05
# 6  Rental Car Location  0.05
# 7   Mexican Restaurant  0.05
# 8   Italian Restaurant  0.05
# 9  Sporting Goods Shop  0.05
#
#
# ----Roselawn----
#                        venue  freq
# 0               Home Service  0.67
# 1                     Garden  0.33
# 2             Adult Boutique  0.00
# 3        Martial Arts School  0.00
# 4   Mediterranean Restaurant  0.00
# 5                Men's Store  0.00
# 6              Metro Station  0.00
# 7         Mexican Restaurant  0.00
# 8  Middle Eastern Restaurant  0.00
# 9         Miscellaneous Shop  0.00
#
#
# ----Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park----
#                  venue  freq
# 0          Coffee Shop  0.14
# 1           Bagel Shop  0.07
# 2   Light Rail Station  0.07
# 3                 Bank  0.07
# 4          Supermarket  0.07
# 5           Restaurant  0.07
# 6                  Pub  0.07
# 7  Fried Chicken Joint  0.07
# 8  American Restaurant  0.07
# 9         Liquor Store  0.07
#
#
# ----The Annex, North Midtown, Yorkville----
#                venue  freq
# 0               Café  0.14
# 1     Sandwich Place  0.14
# 2        Coffee Shop  0.14
# 3           Pharmacy  0.05
# 4  Indian Restaurant  0.05
# 5       Burger Joint  0.05
# 6       Liquor Store  0.05
# 7         Donut Shop  0.05
# 8        Cheese Shop  0.05
# 9          BBQ Joint  0.05
#
#
# ----Berczy Park----
#                 venue  freq
# 0        Cocktail Bar  0.05
# 1         Coffee Shop  0.05
# 2              Bakery  0.05
# 3      Farmers Market  0.04
# 4            Pharmacy  0.04
# 5  Seafood Restaurant  0.04
# 6         Cheese Shop  0.04
# 7            Beer Bar  0.04
# 8          Restaurant  0.04
# 9        Gourmet Shop  0.02
#
#
# ----CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport----
#                  venue  freq
# 0       Airport Lounge  0.13
# 1      Airport Service  0.13
# 2     Airport Terminal  0.13
# 3      Harbor / Marina  0.07
# 4              Airport  0.07
# 5                Plane  0.07
# 6  Rental Car Location  0.07
# 7     Sculpture Garden  0.07
# 8        Boat or Ferry  0.07
# 9             Boutique  0.07
#
#
# ----Central Bay Street----
#                     venue  freq
# 0             Coffee Shop  0.17
# 1                    Café  0.06
# 2              Restaurant  0.04
# 3      Italian Restaurant  0.04
# 4          Sandwich Place  0.04
# 5     Japanese Restaurant  0.03
# 6             Salad Place  0.03
# 7            Burger Joint  0.03
# 8         Bubble Tea Shop  0.03
# 9  Furniture / Home Store  0.01
#
#
# ----Christie----
#                 venue  freq
# 0       Grocery Store  0.25
# 1                Café  0.19
# 2                Park  0.12
# 3  Italian Restaurant  0.06
# 4          Baby Store  0.06
# 5           Nightclub  0.06
# 6  Athletics & Sports  0.06
# 7         Coffee Shop  0.06
# 8         Candy Store  0.06
# 9          Restaurant  0.06
#
#
# ----Church and Wellesley----
#                       venue  freq
# 0               Coffee Shop  0.08
# 1       Japanese Restaurant  0.06
# 2          Sushi Restaurant  0.06
# 3                Restaurant  0.04
# 4                   Gay Bar  0.04
# 5      Fast Food Restaurant  0.03
# 6  Mediterranean Restaurant  0.03
# 7               Men's Store  0.03
# 8                       Pub  0.03
# 9                     Hotel  0.03
#
#
# ----Commerce Court, Victoria Hotel----
#                  venue  freq
# 0          Coffee Shop  0.14
# 1           Restaurant  0.07
# 2                Hotel  0.06
# 3                 Café  0.06
# 4                  Gym  0.04
# 5   Seafood Restaurant  0.03
# 6        Deli / Bodega  0.03
# 7               Bakery  0.03
# 8  American Restaurant  0.03
# 9  Japanese Restaurant  0.03
#
#
# ----First Canadian Place, Underground city----
#                  venue  freq
# 0          Coffee Shop  0.10
# 1                 Café  0.07
# 2                Hotel  0.06
# 3           Restaurant  0.04
# 4                  Gym  0.04
# 5  Japanese Restaurant  0.04
# 6     Asian Restaurant  0.03
# 7          Salad Place  0.03
# 8   Seafood Restaurant  0.03
# 9           Steakhouse  0.03
#
#
# ----Garden District, Ryerson----
#                  venue  freq
# 0          Coffee Shop  0.11
# 1       Clothing Store  0.09
# 2                 Café  0.03
# 3                Hotel  0.03
# 4       Cosmetics Shop  0.03
# 5  Japanese Restaurant  0.03
# 6      Bubble Tea Shop  0.03
# 7       Lingerie Store  0.02
# 8    Electronics Store  0.02
# 9          Pizza Place  0.02
#
#
# ----Harbourfront East, Union Station, Toronto Islands----
#                  venue  freq
# 0          Coffee Shop  0.13
# 1             Aquarium  0.05
# 2                Hotel  0.04
# 3                 Café  0.04
# 4  Fried Chicken Joint  0.03
# 5       Scenic Lookout  0.03
# 6              Brewery  0.03
# 7           Restaurant  0.03
# 8          Pizza Place  0.02
# 9          Music Venue  0.02
#
#
# ----Kensington Market, Chinatown, Grange Park----
#                            venue  freq
# 0                           Café  0.07
# 1                            Bar  0.06
# 2                    Coffee Shop  0.04
# 3          Vietnamese Restaurant  0.04
# 4  Vegetarian / Vegan Restaurant  0.04
# 5                           Park  0.03
# 6            Dumpling Restaurant  0.03
# 7                         Bakery  0.03
# 8                   Burger Joint  0.03
# 9                   Dessert Shop  0.03
#
#
# ----Regent Park, Harbourfront----
#                    venue  freq
# 0            Coffee Shop  0.16
# 1                   Park  0.07
# 2                 Bakery  0.07
# 3                    Pub  0.07
# 4                   Café  0.04
# 5         Breakfast Spot  0.04
# 6                Theater  0.04
# 7            Yoga Studio  0.02
# 8  Performing Arts Venue  0.02
# 9                    Spa  0.02
#
#
# ----Richmond, Adelaide, King----
#              venue  freq
# 0      Coffee Shop  0.09
# 1             Café  0.05
# 2   Clothing Store  0.05
# 3  Thai Restaurant  0.04
# 4       Restaurant  0.04
# 5            Hotel  0.04
# 6              Gym  0.03
# 7      Salad Place  0.02
# 8    Deli / Bodega  0.02
# 9    Burrito Place  0.02
#
#
# ----Rosedale----
#                       venue  freq
# 0                      Park  0.50
# 1                Playground  0.25
# 2                     Trail  0.25
# 3            Adult Boutique  0.00
# 4             Movie Theater  0.00
# 5       Martial Arts School  0.00
# 6  Mediterranean Restaurant  0.00
# 7               Men's Store  0.00
# 8             Metro Station  0.00
# 9        Mexican Restaurant  0.00
#
#
# ----St. James Town----
#               venue  freq
# 0              Café  0.07
# 1       Coffee Shop  0.07
# 2        Restaurant  0.03
# 3    Cosmetics Shop  0.03
# 4            Bakery  0.03
# 5      Cocktail Bar  0.03
# 6    Clothing Store  0.03
# 7              Park  0.02
# 8  Department Store  0.02
# 9          Creperie  0.02
#
#
# ----St. James Town, Cabbagetown----
#                 venue  freq
# 0         Coffee Shop  0.07
# 1  Chinese Restaurant  0.05
# 2                Café  0.05
# 3              Market  0.05
# 4         Pizza Place  0.05
# 5              Bakery  0.05
# 6                 Pub  0.05
# 7  Italian Restaurant  0.05
# 8          Restaurant  0.05
# 9        Liquor Store  0.02
#
#
# ----Toronto Dominion Centre, Design Exchange----
#                  venue  freq
# 0          Coffee Shop  0.11
# 1                Hotel  0.07
# 2                 Café  0.05
# 3           Restaurant  0.04
# 4               Bakery  0.03
# 5          Salad Place  0.03
# 6   Seafood Restaurant  0.03
# 7   Italian Restaurant  0.03
# 8  Japanese Restaurant  0.03
# 9        Deli / Bodega  0.02
#
#
# ----University of Toronto, Harbord----
#                    venue  freq
# 0                   Café  0.15
# 1                 Bakery  0.06
# 2    Japanese Restaurant  0.06
# 3              Bookstore  0.06
# 4         Sandwich Place  0.06
# 5                    Bar  0.06
# 6  College Arts Building  0.03
# 7       Sushi Restaurant  0.03
# 8               Beer Bar  0.03
# 9             Beer Store  0.03
#
#
# ----Enclave of M5E----
#                  venue  freq
# 0          Coffee Shop  0.10
# 1   Italian Restaurant  0.04
# 2   Seafood Restaurant  0.04
# 3           Restaurant  0.03
# 4               Bakery  0.03
# 5                  Pub  0.03
# 6         Cocktail Bar  0.03
# 7                 Café  0.03
# 8                Hotel  0.03
# 9  Japanese Restaurant  0.03
#
#
# ----India Bazaar, The Beaches West----
#                 venue  freq
# 0                Park  0.09
# 1         Pizza Place  0.04
# 2                 Pub  0.04
# 3   Fish & Chips Shop  0.04
# 4             Brewery  0.04
# 5   Food & Drink Shop  0.04
# 6          Board Shop  0.04
# 7      Sandwich Place  0.04
# 8        Liquor Store  0.04
# 9  Light Rail Station  0.04
#
#
# ----Studio District----
#                  venue  freq
# 0          Coffee Shop  0.08
# 1              Brewery  0.06
# 2                 Café  0.06
# 3               Bakery  0.06
# 4  American Restaurant  0.06
# 5            Gastropub  0.06
# 6          Yoga Studio  0.03
# 7                Diner  0.03
# 8   Seafood Restaurant  0.03
# 9          Cheese Shop  0.03
#
#
# ----The Beaches----
#                       venue  freq
# 0         Health Food Store  0.25
# 1                     Trail  0.25
# 2                       Pub  0.25
# 3              Neighborhood  0.25
# 4             Movie Theater  0.00
# 5       Martial Arts School  0.00
# 6  Mediterranean Restaurant  0.00
# 7               Men's Store  0.00
# 8             Metro Station  0.00
# 9        Mexican Restaurant  0.00
#
#
# ----The Danforth West, Riverdale----
#                      venue  freq
# 0         Greek Restaurant  0.17
# 1              Coffee Shop  0.07
# 2       Italian Restaurant  0.07
# 3   Furniture / Home Store  0.05
# 4           Ice Cream Shop  0.05
# 5                     Café  0.05
# 6              Yoga Studio  0.02
# 7       Frozen Yogurt Shop  0.02
# 8                   Lounge  0.02
# 9  Fruit & Vegetable Store  0.02
#
#
# ----Enclave of M4L----
#                   venue  freq
# 0    Light Rail Station  0.12
# 1            Comic Shop  0.06
# 2         Auto Workshop  0.06
# 3            Skate Park  0.06
# 4                   Spa  0.06
# 5         Burrito Place  0.06
# 6  Fast Food Restaurant  0.06
# 7        Farmers Market  0.06
# 8                Garden  0.06
# 9         Garden Center  0.06
#
#
# ----The Danforth  East----
#                        venue  freq
# 0          Convenience Store  0.33
# 1                       Park  0.33
# 2              Metro Station  0.33
# 3             Adult Boutique  0.00
# 4              Movie Theater  0.00
# 5        Martial Arts School  0.00
# 6   Mediterranean Restaurant  0.00
# 7                Men's Store  0.00
# 8         Mexican Restaurant  0.00
# 9  Middle Eastern Restaurant  0.00
#
#
# ----Brockton, Parkdale Village, Exhibition Place----
#                    venue  freq
# 0                   Café  0.12
# 1            Coffee Shop  0.08
# 2         Breakfast Spot  0.08
# 3                 Bakery  0.08
# 4            Yoga Studio  0.04
# 5     Italian Restaurant  0.04
# 6  Performing Arts Venue  0.04
# 7      Convenience Store  0.04
# 8              Nightclub  0.04
# 9             Restaurant  0.04
#
#
# ----Dufferin, Dovercourt Village----
#                        venue  freq
# 0                   Pharmacy  0.12
# 1                     Bakery  0.12
# 2              Grocery Store  0.06
# 3  Middle Eastern Restaurant  0.06
# 4                       Café  0.06
# 5                Supermarket  0.06
# 6                        Bar  0.06
# 7                       Bank  0.06
# 8                Music Venue  0.06
# 9                    Brewery  0.06
#
#
# ----High Park, The Junction South----
#                     venue  freq
# 0                    Café  0.08
# 1      Mexican Restaurant  0.08
# 2         Thai Restaurant  0.08
# 3                  Bakery  0.04
# 4               Gastropub  0.04
# 5    Fast Food Restaurant  0.04
# 6                     Bar  0.04
# 7             Music Venue  0.04
# 8  Furniture / Home Store  0.04
# 9      Italian Restaurant  0.04
#
#
# ----Little Portugal, Trinity----
#                    venue  freq
# 0                    Bar  0.12
# 1       Asian Restaurant  0.05
# 2  Vietnamese Restaurant  0.05
# 3             Restaurant  0.05
# 4            Men's Store  0.05
# 5                   Café  0.05
# 6            Yoga Studio  0.02
# 7              Juice Bar  0.02
# 8      Korean Restaurant  0.02
# 9             Beer Store  0.02
#
#
# ----Parkdale, Roncesvalles----
#                          venue  freq
# 0               Breakfast Spot  0.14
# 1                    Gift Shop  0.14
# 2                  Coffee Shop  0.07
# 3                Movie Theater  0.07
# 4                          Bar  0.07
# 5  Eastern European Restaurant  0.07
# 6           Italian Restaurant  0.07
# 7                      Dog Run  0.07
# 8                    Bookstore  0.07
# 9                 Dessert Shop  0.07
#
#
# ----Runnymede, Swansea----
#                        venue  freq
# 0                Coffee Shop  0.09
# 1                       Café  0.09
# 2           Sushi Restaurant  0.06
# 3                Pizza Place  0.06
# 4                        Pub  0.06
# 5         Italian Restaurant  0.06
# 6                Yoga Studio  0.03
# 7              Burrito Place  0.03
# 8  Latin American Restaurant  0.03
# 9                  Bookstore  0.03

# %% [markdown]
# Create a dataframe from the results

# %%
# Sort venues in descending order
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[2:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# Create dataframe
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Borough', 'Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Borough'] = toronto_grouped['Borough']
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhoods']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 2:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head(10)
# Out:
#             Borough                                       Neighborhood  \
# 0   Central Toronto                                         Davisville
# 1   Central Toronto                                   Davisville North
# 2   Central Toronto                           Forest Hill North & West
# 3   Central Toronto                                      Lawrence Park
# 4   Central Toronto                        Moore Park, Summerhill East
# 5   Central Toronto                                 North Toronto West
# 6   Central Toronto                                           Roselawn
# 7   Central Toronto  Summerhill West, Rathnelly, South Hill, Forest...
# 8   Central Toronto                The Annex, North Midtown, Yorkville
# 9  Downtown Toronto                                        Berczy Park
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0          Dessert Shop        Sandwich Place    Italian Restaurant
# 1                 Hotel      Department Store     Food & Drink Shop
# 2                  Park         Jewelry Store                 Trail
# 3                  Park           Swim School              Bus Line
# 4                  Park           Summer Camp           Yoga Studio
# 5           Coffee Shop        Clothing Store                  Park
# 6          Home Service                Garden                 Diner
# 7           Coffee Shop           Pizza Place            Restaurant
# 8                  Café           Coffee Shop        Sandwich Place
# 9                Bakery          Cocktail Bar           Coffee Shop
#
#   4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0                  Café                   Gym           Coffee Shop
# 1  Gym / Fitness Center                  Park        Breakfast Spot
# 2      Sushi Restaurant                 Diner           Event Space
# 3        Farmers Market           Event Space  Ethiopian Restaurant
# 4                 Diner           Event Space  Ethiopian Restaurant
# 5    Salon / Barbershop            Restaurant   Rental Car Location
# 6    Falafel Restaurant           Event Space  Ethiopian Restaurant
# 7                   Pub           Supermarket      Sushi Restaurant
# 8             BBQ Joint        History Museum                   Pub
# 9            Restaurant              Beer Bar              Pharmacy
#
#   7th Most Common Venue 8th Most Common Venue        9th Most Common Venue  \
# 0           Pizza Place      Sushi Restaurant               Farmers Market
# 1           Pizza Place          Dance Studio               Sandwich Place
# 2  Ethiopian Restaurant           Escape Room            Electronics Store
# 3           Escape Room     Electronics Store  Eastern European Restaurant
# 4           Escape Room     Electronics Store  Eastern European Restaurant
# 5                  Café    Chinese Restaurant               Cosmetics Shop
# 6           Escape Room     Electronics Store  Eastern European Restaurant
# 7    Light Rail Station   Fried Chicken Joint                         Bank
# 8          Liquor Store           Cheese Shop    Middle Eastern Restaurant
# 9           Cheese Shop    Seafood Restaurant               Farmers Market
#
#         10th Most Common Venue
# 0          Fried Chicken Joint
# 1                      Dog Run
# 2  Eastern European Restaurant
# 3          Dumpling Restaurant
# 4          Dumpling Restaurant
# 5          Sporting Goods Shop
# 6          Dumpling Restaurant
# 7                   Bagel Shop
# 8                  Pizza Place
# 9                Shopping Mall

# %% [markdown]
# Create a cluster map

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop(['Borough', 'Neighborhoods'], 1)

# run k-means clustering
kmeans = KMeans(init='k-means++', n_clusters=kclusters, random_state=1, max_iter=1000).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]

# add clustering labels
neighborhoods_venues_sorted['Cluster Labels'] = kmeans.labels_

toronto_merged = df_toronto_borough.copy()

# merge toronto_grouped with df_toronto_borough to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.drop(['Borough'], axis=1).set_index('Neighborhood'), on='Neighborhood')

# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_0d0ec410483c44ef851881c1f1deb41e%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0d0ec410483c44ef851881c1f1deb41e%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_0d0ec410483c44ef851881c1f1deb41e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_0d0ec410483c44ef851881c1f1deb41e%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...
